# %%
# Testing Your Code
#  test_sum.py
def test_sum():
    assert sum([1, 2, 3]) == 6, "Should be 6"

if __name__ == "__main__":
    test_sum()
    print("Everything passed")
# Out:
# Everything passed

# %%
# Testsing Your Code
# test_sum2.py
def test_sum():
    assert sum([1, 2, 3]) == 6, "Should be 6"

def test_sum_tuple():
    assert sum((1, 2, 2)) == 6, "Should be 6"   # Error because of sum((1, 2, 2))

if __name__ == "__main__":
    test_sum()
    test_sum_tuple()
    print("Everything passed")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[10], line 11
#       9 if __name__ == "__main__":
#      10     test_sum()
# ---> 11     test_sum_tuple()
#      12     print("Everything passed")
#
# Cell In[10], line 7, in test_sum_tuple()
#       6 def test_sum_tuple():
# ----> 7     assert sum((1, 2, 2)) == 6, "Should be 6"
#
# AssertionError: Should be 6

# %%
# Testing Your Code
def test_sum():
    assert sum([1, 2, 3]) == 6, "Should be 6"
def test_sum_tuple():
    assert sum((1, 2, 2)) == 6, "Should be 6"
